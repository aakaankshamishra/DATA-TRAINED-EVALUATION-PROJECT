# %% [markdown]
# # Problem Statement:
# Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %%
#importing some important libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the Dataset.
GPPD = pd.read_csv(r'https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
GPPD
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# Key attributes of the database
# The database includes the following indicators:
# country (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5] country_long (text): longer form of the country designation name (text): name or title of the power plant, generally in Romanized form gppd_idnr (text): 10 or 12 character identifier for the power plant capacity_mw (number): electrical generating capacity in megawatts latitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326) longitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326) primary_fuel (text): energy source used in primary electricity generation or export other_fuel1 (text): energy source used in electricity generation or export other_fuel2 (text): energy source used in electricity generation or export other_fuel3 (text): energy source used in electricity generation or export commissioning_year (number): year of plant operation, weighted by unit-capacity when data is available owner (text): majority shareholder of the power plant, generally in Romanized form source (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form url (text): web document corresponding to the source field geolocation_source (text): attribution for geolocation information wepp_id (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database. year_of_capacity_data (number): year the capacity information was reported generation_gwh_2013 (number): electricity generation in gigawatt-hours reported for the year 2013 generation_gwh_2014 (number): electricity generation in gigawatt-hours reported for the year 2014 generation_gwh_2015 (number): electricity generation in gigawatt-hours reported for the year 2015 generation_gwh_2016 (number): electricity generation in gigawatt-hours reported for the year 2016 generation_gwh_2017 (number): electricity generation in gigawatt-hours reported for the year 2017 generation_gwh_2018 (number): electricity generation in gigawatt-hours reported for the year 2018 generation_gwh_2019 (number): electricity generation in gigawatt-hours reported for the year 2019 generation_data_source (text): attribution for the reported generation information estimated_generation_gwh_2013 (number): estimated electricity generation in gigawatt-hours for the year 2013 estimated_generation_gwh_2014 (number): estimated electricity generation in gigawatt-hours for the year 2014 estimated_generation_gwh_2015 (number): estimated electricity generation in gigawatt-hours for the year 2015 estimated_generation_gwh_2016 (number): estimated electricity generation in gigawatt-hours for the year 2016 estimated_generation_gwh_2017 (number): estimated electricity generation in gigawatt-hours for the year 2017 'estimated_generation_note_2013(text): label of the model/method used to estimate generation for the year 2013estimated_generation_note_2014(text): label of the model/method used to estimate generation for the year 2014estimated_generation_note_2015(text): label of the model/method used to estimate generation for the year 2015estimated_generation_note_2016(text): label of the model/method used to estimate generation for the year 2016estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017

# %%
GPPD.shape
# Out:
# (907, 27)

# %%
GPPD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
GPPD.nunique()#unique elements in each column
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
#checking for null values
GPPD.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
#Checking with the help of heatmap
plt.figure(figsize=(11,10))
sns.heatmap(GPPD.isna(), cmap='binary_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Columns like other_fuel2,other_fuel3,wepp_id,estimated_generation_gwh have no data available, so they will be dropped.

# %% [markdown]
# # Getting the basic summary and statistical information of the data.

# %%
GPPD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
GPPD.dtypes[GPPD.dtypes == 'object'] #Identifying the Categorical Columns
# Out:
# country                   object
# country_long              object
# name                      object
# gppd_idnr                 object
# primary_fuel              object
# other_fuel1               object
# other_fuel2               object
# owner                     object
# source                    object
# url                       object
# geolocation_source        object
# generation_data_source    object
# dtype: object

# %% [markdown]
# GPPD.dtypes[GPPD.dtypes != 'object']#Identifying the Continuous/discrete Columns

# %%
#Statistical description of dataset
GPPD.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %% [markdown]
# From the above description it is observed that columns like capacity_mw, generation_gwh_2013,generation_gwh_2014,generation_gwh_2015,generation_gwh_2016,generation_gwh_2017 may contain outliers since there is a huge difference between 75% and max and their respective means and 50% also are significantly different.
#
# A higher Std than mean in above columns indicates skewness.

# %%
GPPD.drop(columns=['estimated_generation_gwh','wepp_id','owner','other_fuel3','other_fuel2','other_fuel1'],inplace=True)

# %%
GPPD
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
#dropping columns url,country,country_long ,name, gppd_idnr since they don't contribute to building a good model for predicting the target variable values.
GPPD.drop(columns=['country','country_long','name','gppd_idnr','url'],inplace=True)
GPPD
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal                 NaN
# 2           39.2   21.9038    69.3732         Wind                 NaN
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar                 NaN
# 904         25.5   15.2758    75.5811         Wind                 NaN
# 905         80.0   24.3500    73.7477         Coal                 NaN
# 906         16.5    9.9344    77.4768         Wind                 NaN
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# ...

# %%
GPPD.dtypes[GPPD.dtypes == 'object'] #Identifying the Categorical Columns
# Out:
# primary_fuel              object
# source                    object
# geolocation_source        object
# generation_data_source    object
# dtype: object

# %%
GPPD.source.value_counts()
# Out:
# Central Electricity Authority                                  519
# CDM                                                            124
# Lancosola                                                       10
# National Renewable Energy Laboratory                             8
# National Thermal Power Corporation (NTPC)                        6
#                                                               ...
# Harsha Engineers Limited                                         1
# Godawari Energy ltd                                              1
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Yashwantrao Krishna ssk                                          1
# Name: source, Length: 191, dtype: int64

# %%
GPPD.generation_data_source.value_counts()
# Out:
# Central Electricity Authority    449
# Name: generation_data_source, dtype: int64

# %%
GPPD.geolocation_source.value_counts()
# Out:
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
#dropping columns generation_data_source and source since they don't contribute to building a good model for predicting the target variable values.
GPPD.drop(columns=['generation_data_source','source'],inplace=True)
GPPD
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal                 NaN
# 2           39.2   21.9038    69.3732         Wind                 NaN
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar                 NaN
# 904         25.5   15.2758    75.5811         Wind                 NaN
# 905         80.0   24.3500    73.7477         Coal                 NaN
# 906         16.5    9.9344    77.4768         Wind                 NaN
#
#                        geolocation_source  year_of_capacity_data  \
# ...

# %%
GPPD.isnull().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# commissioning_year       380
# geolocation_source        19
# year_of_capacity_data    388
# generation_gwh_2013      907
# generation_gwh_2014      509
# generation_gwh_2015      485
# generation_gwh_2016      473
# generation_gwh_2017      467
# generation_gwh_2018      459
# generation_gwh_2019      907
# dtype: int64

# %% [markdown]
# # Checking for unique categories in the categorical columns with null values

# %%
GPPD.dtypes[GPPD.dtypes == 'object'] #Identifying the Categorical Columns
# Out:
# primary_fuel          object
# geolocation_source    object
# dtype: object

# %%
GPPD.geolocation_source.isnull().sum()
# Out:
# 19

# %%
GPPD.geolocation_source.unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %% [markdown]
# There are 3 unique categories in geolocation_source.

# %%
sns.countplot(GPPD.geolocation_source)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %%
GPPD.geolocation_source.isnull().sum()/908*100
# Out:
# 2.092511013215859

# %%
GPPD.geolocation_source.mode() # most frequently occuring value.
# Out:
# 0    WRI
# dtype: object

# %%
(GPPD['geolocation_source'] == 'WRI').sum()/GPPD.geolocation_source.count()*100 #checking the % share of most frequently occuring value.
# Out:
# 86.14864864864865

# %% [markdown]
# # Therefore imputing ' WRI' to NaN values in geolocation_source column

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent',verbose = 0 )

# %%
si = si.fit(GPPD[['geolocation_source']])

# %%
GPPD[['geolocation_source']] = si.transform(GPPD[['geolocation_source']])

# %%
GPPD[['geolocation_source']].isnull().sum()
# Out:
# geolocation_source    0
# dtype: int64

# %% [markdown]
# There are no more null values in 'geolocation_source' column.
#
# Checking for Null values in continuous / discrete columns.

# %%
GPPD.select_dtypes(exclude = object).isnull().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# commissioning_year       380
# year_of_capacity_data    388
# generation_gwh_2013      907
# generation_gwh_2014      509
# generation_gwh_2015      485
# generation_gwh_2016      473
# generation_gwh_2017      467
# generation_gwh_2018      459
# generation_gwh_2019      907
# dtype: int64

# %%
GPPD.latitude
# Out:
# 0      28.1839
# 1      24.7663
# 2      21.9038
# 3      23.8712
# 4      21.9603
#         ...
# 902    16.2949
# 903    12.8932
# 904    15.2758
# 905    24.3500
# 906     9.9344
# Name: latitude, Length: 907, dtype: float64

# %%
GPPD.longitude
# Out:
# 0      73.2407
# 1      74.6090
# 2      69.3732
# 3      91.3602
# 4      82.4091
#         ...
# 902    77.3568
# 903    78.1654
# 904    75.5811
# 905    73.7477
# 906    77.4768
# Name: longitude, Length: 907, dtype: float64

# %% [markdown]
# # Using KNN Imputation technique for imputing missing data.

# %%
from sklearn.impute import KNNImputer

# %%
imp = KNNImputer(n_neighbors=2)

# %%
GPPD[['latitude','longitude']] = imp.fit_transform(GPPD[['latitude','longitude']])

# %%
GPPD[['latitude','longitude']].isnull().sum()
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# There are no more values missing from 'latitude' and 'longitude' columns.

# %%
GPPD.commissioning_year.isnull().sum()/908*100
# Out:
# 41.85022026431718

# %%
GPPD.commissioning_year.mode()
# Out:
# 0    2015.0
# dtype: float64

# %%
GPPD.commissioning_year.mode()
# Out:
# 0    2015.0
# dtype: float64

# %%
(GPPD['commissioning_year'] == 2013.0).sum()/GPPD.commissioning_year.count()*100 #checking the % share of most frequently occuring value.
# Out:
# 4.743833017077799

# %%
GPPD.commissioning_year.mean()
# Out:
# 1997.0910815939278

# %%
GPPD.commissioning_year.median()
# Out:
# 2001.0

# %%
(GPPD['commissioning_year'] == 1996.0).sum()/GPPD.commissioning_year.count()*100 #checking the % share of mean year value.
# Out:
# 2.4667931688804554

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['commissioning_year']])
GPPD[['commissioning_year']] = si.transform(GPPD[['commissioning_year']])
GPPD[['commissioning_year']].isnull().sum()
# Out:
# commissioning_year    0
# dtype: int64

# %%
GPPD.commissioning_year = GPPD.commissioning_year.astype('int64') #converting to int data type.

# %%
GPPD.commissioning_year
# Out:
# 0      2011
# 1      2001
# 2      2001
# 3      2004
# 4      2015
#        ...
# 902    2016
# 903    2001
# 904    2001
# 905    2001
# 906    2001
# Name: commissioning_year, Length: 907, dtype: int64

# %%
GPPD.year_of_capacity_data.value_counts()
# Out:
# 2019.0    519
# Name: year_of_capacity_data, dtype: int64

# %% [markdown]
# Dropping column year_of_capacity_data as all the values in it are '2018.0'

# %%
GPPD.drop(columns = 'year_of_capacity_data',inplace = True)

# %%
GPPD.shape
# Out:
# (907, 13)

# %%
GPPD.isnull().sum()
# Out:
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# geolocation_source       0
# generation_gwh_2013    907
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# generation_gwh_2019    907
# dtype: int64

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnum=1
X = GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source','latitude','longitude','commissioning_year',])
for col in X:
    if plotnum<=16:
        plt.subplot(4,4,plotnum)
        sns.boxplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# outliers exist, therefore imputing with KNN imputation technique.

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['generation_gwh_2018']])
GPPD[['generation_gwh_2018']] = si.transform(GPPD[['generation_gwh_2018']])
GPPD[['generation_gwh_2018']].isnull().sum()
# Out:
# generation_gwh_2018    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['generation_gwh_2014']])
GPPD[['generation_gwh_2014']] = si.transform(GPPD[['generation_gwh_2014']])
GPPD[['generation_gwh_2014']].isnull().sum()
# Out:
# generation_gwh_2014    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['generation_gwh_2015']])
GPPD[['generation_gwh_2015']] = si.transform(GPPD[['generation_gwh_2015']])
GPPD[['generation_gwh_2015']].isnull().sum()
# Out:
# generation_gwh_2015    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['generation_gwh_2016']])
GPPD[['generation_gwh_2016']] = si.transform(GPPD[['generation_gwh_2016']])
GPPD[['generation_gwh_2016']].isnull().sum()
# Out:
# generation_gwh_2016    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,strategy = 'median',verbose = 0 )
si = si.fit(GPPD[['generation_gwh_2017']])
GPPD[['generation_gwh_2017']] = si.transform(GPPD[['generation_gwh_2017']])
GPPD[['generation_gwh_2017']].isnull().sum()
# Out:
# generation_gwh_2017    0
# dtype: int64

# %%
GPPD.isnull().sum()
# Out:
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# geolocation_source       0
# generation_gwh_2013    907
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# generation_gwh_2019    907
# dtype: int64

# %%
GPPD.drop(['generation_gwh_2013','generation_gwh_2019'], axis=1, inplace=True)

# %%
GPPD.isna().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# commissioning_year     0
# geolocation_source     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %% [markdown]
# There are no more null values in the dataframe.

# %%
#Extracting the age of Power plants from commissioning_year column will give a better insight into its relationship with target column data.
GPPD['Age'] = GPPD['commissioning_year'].apply(lambda y: 2021 - y)

# %%
GPPD.drop(columns=['commissioning_year'],inplace=True)
GPPD
# Out:
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5   28.1839    73.2407        Solar
# 1           98.0   24.7663    74.6090         Coal
# 2           39.2   21.9038    69.3732         Wind
# 3          135.0   23.8712    91.3602          Gas
# 4         1800.0   21.9603    82.4091         Coal
# ..           ...       ...        ...          ...
# 902       1600.0   16.2949    77.3568         Coal
# 903          3.0   12.8932    78.1654        Solar
# 904         25.5   15.2758    75.5811         Wind
# 905         80.0   24.3500    73.7477         Coal
# 906         16.5    9.9344    77.4768         Wind
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory           801.123775
# 1                                     WRI           801.123775
# 2                                     WRI           801.123775
# 3                                     WRI           617.789264
# ...

# %% [markdown]
# # Exploration of the data

# %%
#Analyzing the continuous data type Target column
GPPD.capacity_mw
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 907, dtype: float64

# %%
sns.distplot(GPPD.capacity_mw)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %%
GPPD.select_dtypes(include = object).isnull().sum()
# Out:
# primary_fuel          0
# geolocation_source    0
# dtype: int64

# %%
GPPD.capacity_mw.skew()
# Out:
# 3.123576153626497

# %% [markdown]
# Distribution of data is right skewed.

# %% [markdown]
# Analyzing Feature columns with Continuous Data.

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
for col in GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source']):
    if plotnum<=10:
        plt.subplot(4,4,plotnum)
        sns.distplot(GPPD[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
#capacity_mw vs continuous / discrete data type columns
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
y = GPPD['capacity_mw']
X =  GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source'])
for col in X:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.scatterplot(X[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('capacity_mw',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# We can observe a linear relationship between columns generation_gwh_2013,generation_gwh_2014,generation_gwh_2015,generation_gwh_2016,generation_gwh_2017

# %%
plt.figure(figsize=(6,6),facecolor='white')
X = ['generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']
for col in X:
    sns.lmplot(x = col,y = 'capacity_mw',data = GPPD)

# %%
#capacity_mw vs categorical data type columns
plt.figure(figsize=(18,25),facecolor='pink')
plotnum=1
y = GPPD['capacity_mw']
X = GPPD[['primary_fuel','geolocation_source']]
for col in X:
    if plotnum<=23:
        plt.subplot(9,1,plotnum)
        sns.barplot(X[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('capacity_mw',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %%
#Analyzing the categorical data type Target column
GPPD.primary_fuel.unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %% [markdown]
# There are 8 unique categories in primary_fuel

# %%
sns.countplot(GPPD['primary_fuel'], palette="Set2")
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %%
GPPD.primary_fuel.value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
labels = 'Coal','Hydro','Solar','Wind','Gas','Biomass','Oil','Nuclear'
fig, ax = plt.subplots()
ax.pie(GPPD['primary_fuel'].value_counts(),labels = labels,radius =2,autopct = '%1.2f%%', shadow=True,)
plt.show()

# %%
#Interpreting Relationship between Dependent Variable and Independent Variables
#'primary_fuel' vs Continuous/Discrete Data Columns
plt.figure(figsize=(20,25),facecolor='pink')
plotnum=1
y = GPPD['primary_fuel']
X =  GPPD.drop(columns=['primary_fuel','geolocation_source'])
for col in X:
    if plotnum<=15:
        plt.subplot(5,2,plotnum)
        sns.barplot(y,X[col])
        plt.xlabel('primary_fuel',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnum+=1
plt.tight_layout()

# %%
#'primary_fuel' vs Categorical Data Columns
plt.figure(figsize=(18,25),facecolor='white')
plotnum=1
y = GPPD['primary_fuel']
X =  GPPD[['geolocation_source']]
for col in X:
    if plotnum<=23:
        plt.subplot(9,1,plotnum)
        sns.countplot(X[col],hue =y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('Count',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %%
#Checking for Outliers in columns with continuous distribution
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
X = GPPD.drop(columns=['primary_fuel','geolocation_source'])
for col in X:
    if plotnum<=16:
        plt.subplot(4,4,plotnum)
        sns.boxplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# All columns except latitude have a lot of outliers.

# %%
GPPD2 = GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source']).copy()

# %%
from scipy.stats import zscore
zscor = zscore(GPPD2)
z_score_abs = np.abs(zscor)

GPPD3 = GPPD2[(z_score_abs < 3).all(axis=1)] #taking 3 as threshold value

# %%
GPPD3.shape
# Out:
# (851, 8)

# %%
GPPD2.shape
# Out:
# (907, 8)

# %% [markdown]
# # Data loss %:

# %%
loss=(908-852)/908 * 100
loss
# Out:
# 6.167400881057269

# %%
#Using Z score method to reduce outliers
dropindx = GPPD.index.difference(GPPD3.index)
GPPD.drop(dropindx,inplace = True) #dropping the outliers from original features Dataframe
GPPD.shape
# Out:
# (851, 11)

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
X = GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source'])
for col in X:
    if plotnum<=16:
        plt.subplot(4,4,plotnum)
        sns.boxplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
#Checking for Skewness in Data
GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source']).skew()
# Out:
# latitude              -0.119551
# longitude              0.918693
# generation_gwh_2014    2.943026
# generation_gwh_2015    2.714999
# generation_gwh_2016    2.645786
# generation_gwh_2017    2.546541
# generation_gwh_2018    2.597029
# Age                    1.280800
# dtype: float64

# %% [markdown]
# # Reducing skewness further using PowerTransformer

# %%
from sklearn.preprocessing import PowerTransformer
GPPDtrans= PowerTransformer(method='yeo-johnson', standardize=True)
GPPD4 = GPPD.drop(columns=['capacity_mw','primary_fuel','geolocation_source']).copy()
transformed= GPPDtrans.fit_transform(GPPD4)
transformed = pd.DataFrame(transformed, columns=GPPD4.columns) #to convert numpy array back into dataframe
transformed.skew()
# Out:
# latitude              -0.069485
# longitude              0.000058
# generation_gwh_2014    0.232399
# generation_gwh_2015    0.163587
# generation_gwh_2016    0.147035
# generation_gwh_2017    0.127152
# generation_gwh_2018    0.133691
# Age                    0.026563
# dtype: float64

# %%
transformed.index = GPPD.index
GPPD[['latitude','longitude','generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','Age']]=transformed[['latitude','longitude','generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','Age']]
GPPD
# Out:
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5  1.171257  -0.930084        Solar
# 1           98.0  0.596967  -0.511383         Coal
# 2           39.2  0.120520  -2.364717         Wind
# 3          135.0  0.447512   2.442641          Gas
# 4         1800.0  0.129881   1.252442         Coal
# ..           ...       ...        ...          ...
# 902       1600.0 -0.798944   0.217674         Coal
# 903          3.0 -1.345620   0.407395        Solar
# 904         25.5 -0.963692  -0.237493         Wind
# 905         80.0  0.527406  -0.770182         Coal
# 906         16.5 -1.812657   0.246488         Wind
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory            -0.044061
# 1                                     WRI            -0.044061
# 2                                     WRI            -0.044061
# 3                                     WRI            -0.268922
# ...

# %%
GPPD2 =GPPD.copy()

# %% [markdown]
# # Encoding the categorical Feature Columns.

# %%
#Encoding using get_dummies()
dumm = pd.get_dummies(GPPD[['geolocation_source','primary_fuel']],drop_first = False)
GPPD2 = GPPD2.join(dumm)
GPPD2.drop(columns = ['geolocation_source','primary_fuel'],axis = 1, inplace = True)
GPPD2
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2014  \
# 0            2.5  1.171257  -0.930084            -0.044061
# 1           98.0  0.596967  -0.511383            -0.044061
# 2           39.2  0.120520  -2.364717            -0.044061
# 3          135.0  0.447512   2.442641            -0.268922
# 4         1800.0  0.129881   1.252442             1.426798
# ..           ...       ...        ...                  ...
# 902       1600.0 -0.798944   0.217674            -0.044061
# 903          3.0 -1.345620   0.407395            -0.044061
# 904         25.5 -0.963692  -0.237493            -0.044061
# 905         80.0  0.527406  -0.770182            -0.044061
# 906         16.5 -1.812657   0.246488            -0.044061
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0              -0.049141            -0.046103            -0.035226
# 1              -0.049141            -0.046103            -0.035226
# ...

# %%
#Finding Correlation
GPPD_corr = GPPD2.corr()
GPPD_corr
# Out:
#                                                     capacity_mw  latitude  \
# capacity_mw                                            1.000000  0.050307
# latitude                                               0.050307  1.000000
# longitude                                              0.256838 -0.068115
# generation_gwh_2014                                    0.466805  0.105999
# generation_gwh_2015                                    0.519018  0.100775
# generation_gwh_2016                                    0.582540  0.119213
# generation_gwh_2017                                    0.603896  0.100141
# generation_gwh_2018                                    0.613179  0.107471
# Age                                                   -0.331141 -0.106203
# geolocation_source_Industry About                     -0.231883  0.196149
# geolocation_source_National Renewable Energy La...    -0.032010  0.073447
# geolocation_source_WRI                                 0.234923 -0.207771
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(GPPD_corr,annot=True,linewidth=1,  cmap='gist_rainbow_r')
plt.show()

# %%
#Visualizing correlation of feature columns with label column.
plt.figure(figsize = (22,20))
GPPD2.corr()['capacity_mw'].sort_values(ascending = False).drop(['capacity_mw']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('capacity_mw',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
X = GPPD2.drop(columns = ['capacity_mw'])
y = GPPD2['capacity_mw']
scaler= StandardScaler()
scaled_X = scaler.fit_transform(X)

# %% [markdown]
# # Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["Features"] = X.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif.head(10)
# Out:
#                                             Features        vif
# 0                                           latitude   1.186160
# 1                                          longitude   1.366723
# 2                                generation_gwh_2014   3.735443
# 3                                generation_gwh_2015   6.265679
# 4                                generation_gwh_2016  10.112133
# 5                                generation_gwh_2017  10.452660
# 6                                generation_gwh_2018   9.463983
# 7                                                Age   1.383426
# 8                  geolocation_source_Industry About        inf
# 9  geolocation_source_National Renewable Energy L...        inf

# %%
#Principle Component Analysis
from sklearn.decomposition import PCA
pca = PCA()
principleComponents = pca.fit_transform(scaled_X)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# # Feature engineering and feature selection
# Kbest

# %%
from sklearn.feature_selection import SelectKBest, f_classif
bestfeat = SelectKBest(score_func = f_classif, k = 19)
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(19,'Score'))
# Out:
#                                               Feature     Score
# 13                                   primary_fuel_Gas  5.619707
# 6                                 generation_gwh_2018  4.794625
# 5                                 generation_gwh_2017  4.641176
# 4                                 generation_gwh_2016  4.269304
# 15                               primary_fuel_Nuclear  3.637388
# 18                                  primary_fuel_Wind  3.564033
# 2                                 generation_gwh_2014  3.393717
# 8                   geolocation_source_Industry About  3.385337
# 10                             geolocation_source_WRI  3.265825
# 17                                 primary_fuel_Solar  3.197604
# 3                                 generation_gwh_2015  3.143672
# 12                                  primary_fuel_Coal  3.143098
# 16                                   primary_fuel_Oil  2.457972
# 7                                                 Age  2.108357
# ...

# %%
#Dropping highly multicollinear column: 'generation_gwh_2016'.
x_best = X.drop(columns=['generation_gwh_2016']).copy()
scaled_x_best = scaler.fit_transform(x_best)

# %% [markdown]
# # Model Building for the prediction

# %%
#Regression Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
#Finding the Best Random State
from sklearn.ensemble import RandomForestRegressor
maxAcc = 0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(scaled_x_best,y,test_size = .22, random_state = i)
    modRF =  RandomForestRegressor()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc  = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print(f"Best Accuracy is: {maxAcc} on random_state: {maxRS}")
# Out:
# Best Accuracy is: 0.8570391577389521 on random_state: 16

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_x_best,y,test_size = .22, random_state =16)

# %% [markdown]
# # importing some Base models

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.svm import SVR

# %%
from sklearn.metrics import r2_score,mean_squared_error
rf = RandomForestRegressor(n_estimators=600, random_state=16, max_depth=4, n_jobs=-1)
Gb = GradientBoostingRegressor(n_estimators=600, random_state=16, learning_rate=0.1,max_depth=4,subsample=0.1,n_iter_no_change=50 )

SV= SVR(kernel='linear')
lr=LinearRegression(normalize=True)

# %% [markdown]
# # Training All the Models

# %%
#Random forest regressor

rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=600, n_jobs=-1, random_state=16)

# %%
#Support Vector regressor

SV.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
#Gradient boosting Regressor

Gb.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=4, n_estimators=600, n_iter_no_change=50,
#                           random_state=16, subsample=0.1)

# %%
#Linear regression regressor

lr.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# All models have been trained.

# %%
#Random forest Regression Model prediction score
y_pred_rf = rf.predict(x_test)
print('this is  the  r2_score  :', r2_score(y_pred_rf, y_test))
print('this  is  the mean_squared_error:', mean_squared_error(y_pred_rf, y_test))
# Out:
# this is  the  r2_score  : 0.8056480764128804
# this  is  the mean_squared_error: 27722.194318050984

# %%
#Verifying the performance of the model by graph
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=y_pred_rf,color='red')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual capacity")
plt.ylabel("Predicted capacity")
plt.title("Random  forest regressor")
plt.show()

# %%
#Gradient boosting Regression Model
Gb = GradientBoostingRegressor(n_estimators=450, random_state=16, learning_rate=0.1,max_depth=2,subsample=0.1,n_iter_no_change=4)
Gb.fit(x_train, y_train)
GB_pred = Gb.predict(x_test)
print('this is  the  r2_score  :', r2_score(GB_pred, y_test))
print('this  is  the mean_squared_error:', mean_squared_error(GB_pred, y_test))
# Out:
# this is  the  r2_score  : 0.7759112865015609
# this  is  the mean_squared_error: 28202.845581838534

# %%
#Verifying the performance of the model by graph
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=GB_pred,color='red')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual capacity")
plt.ylabel("Predicted capacity")
plt.title("Gradient boosting regressor")
plt.show()

# %%
#Support Vector machine regressor Model
Sv_pred = SV.predict(x_test)
print('this is  the  r2_score  :', r2_score(Sv_pred, y_test))
print('this  is  the mean_squared_error:', mean_squared_error(Sv_pred, y_test))
# Out:
# this is  the  r2_score  : -0.623379958239602
# this  is  the mean_squared_error: 75254.15450688721

# %%
#Verifying the performance of the model by graph
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=Sv_pred,color='g')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual capacity")
plt.ylabel("Predicted capacity")
plt.title("SVC regressor")
plt.show()

# %%
#Linear Regression model
Lr_pred = lr.predict(x_test)
print('this is  the  r2_score  :', r2_score(Lr_pred, y_test))
print('this  is  the mean_squared_error:', mean_squared_error(Lr_pred, y_test))
# Out:
# this is  the  r2_score  : 0.46919952865214143
# this  is  the mean_squared_error: 67119.09688493259

# %%
#Verifying the performance of the model by graph
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=Lr_pred,color='g')
plt.plot(y_test,y_test,color='black')
plt.xlabel("Actual capacity")
plt.ylabel("Predicted capacity")
plt.title("Linear regressor")
plt.show()

# %%
#Adaboost regressor model
from sklearn.ensemble import AdaBoostRegressor
ab = AdaBoostRegressor(n_estimators=600, random_state=16,learning_rate=0.1)
ab.fit(x_train, y_train)
ab_pred = ab.predict(x_test)
print('this is  the  r2_score  :', r2_score(ab_pred, y_test))
print('this  is  the mean_squared_error:', mean_squared_error(ab_pred, y_test))
# Out:
# this is  the  r2_score  : 0.3995418860104297
# this  is  the mean_squared_error: 62560.37550739231

# %%
#Verifying the performance of the model by graph
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=ab_pred,color='g')
plt.plot(y_test,y_test,color='black')
plt.xlabel("Actual capacity")
plt.ylabel("Predicted capacity")
plt.title("Adabost regressor")
plt.show()

# %% [markdown]
# # Model Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score

# %%
#Random forest Regression
cross_val_score(rf,scaled_x_best,y,cv=6).mean()
# Out:
# 0.754784417820297

# %%
#Gradient boosting Regression
cross_val_score(Gb,scaled_x_best,y,cv=6).mean()
# Out:
# 0.7470245465957105

# %%
#SV Regression
cross_val_score(SV,scaled_x_best,y,cv=6).mean()
# Out:
# 0.4651866551444693

# %%
#Linear Regression
cross_val_score(lr,scaled_x_best,y,cv=6).mean()
# Out:
# 0.5645538357159278

# %%
#Adaboost regression
cross_val_score(ab,scaled_x_best,y,cv=6).mean()
# Out:
# 0.58123094968254

# %% [markdown]
# # HyperParameter Tuning
# for Random forest Using GridsearchCV

# %%
parameter = {'n_estimators':[30,60,80,100,200],
             'max_depth': [1,2,3,4],
             'max_samples':[0,0.01,0.001,0.1,1],
             'criterion':['mse','mae'],
             'max_features':["auto","sqrt","log2"]}

# %%
GridCV = GridSearchCV(RandomForestRegressor(),parameter,cv=6,n_jobs = -1,verbose = 1)
GridCV.fit(x_train,y_train)
# Out:
# Fitting 6 folds for each of 600 candidates, totalling 3600 fits
# GridSearchCV(cv=6, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [1, 2, 3, 4],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'max_samples': [0, 0.01, 0.001, 0.1, 1],
#                          'n_estimators': [30, 60, 80, 100, 200]},
#              verbose=1)

# %%
GridCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'max_samples': 0.1,
#  'n_estimators': 200}

# %%
Best_mod1 = RandomForestRegressor(n_estimators = 80,criterion = 'mae', max_depth= 4, max_features = 'auto',max_samples=0.1)
Best_mod1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mae', max_depth=4, max_samples=0.1,
#                       n_estimators=80)

# %%
rfpred = Best_mod1.predict(x_test)
acc = r2_score(y_test,rfpred)
print(acc*100)
# Out:
# 86.45659581071348

# %%
#Saving The Model
import joblib
joblib.dump(Best_mod1,"BestModelpowercapacity.pkl")
# Out:
# ['BestModelpowercapacity.pkl']

# %%
#prediction by The Model
import numpy as np
a = np.array(y_test)
predicted = np.array(Best_mod1.predict(x_test))
df_com = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
df_com
# Out:
#      Original    Predicted
# 0        21.0    43.310438
# 1       920.0   699.330375
# 2         1.0    17.793563
# 3        16.0    27.735437
# 4         5.0    18.589813
# ..        ...          ...
# 183    1800.0  1363.985000
# 184      15.0    20.621688
# 185      81.5    22.379188
# 186     135.0   205.456437
# 187      90.0   113.335063
#
# [188 rows x 2 columns]
